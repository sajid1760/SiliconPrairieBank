# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../../../credit_card/credit_card_tableau.csv')

# %%
df.head()
# Out:
#    Applicant ID  Gender Car Ownership Property Ownership Employment Status  \
# 0       5008804    Male           Car      Owns Property          Employed
# 1       5008806    Male           Car      Owns Property          Employed
# 2       5008808  Female        No Car      Owns Property          Employed
# 3       5008812  Female        No Car      Owns Property        Unemployed
# 4       5008815    Male           Car      Owns Property          Employed
#
#    Number of Children  Family Size  Lenth of Time Owned Credit Card (months)  \
# 0                   0            2                                        15
# 1                   0            2                                        29
# 2                   0            1                                         4
# 3                   0            1                                        20
# 4                   0            2                                         5
#
# ...

# %%
df.columns
# Out:
# Index(['Applicant ID', 'Gender', 'Car Ownership', 'Property Ownership',
#        'Employment Status', 'Number of Children', 'Family Size',
#        'Lenth of Time Owned Credit Card (months)', 'Total Income (Yuan)',
#        'Age (Years)', 'Years Employed', 'Income Type', 'Education Type',
#        'Family Status', 'Housing Type', 'Occupation Type', 'Approval'],
#       dtype='object')

# %%
df1000 = df.sample(n=1000, random_state=1000)

# %%
df1000.to_json("credit_card_datatable.json", orient='records')

# %%
dfl = pd.read_csv('../../../loan_data/loan_data_tableau_final.csv')

# %%
dfl.head()
# Out:
#    Applicant Id  loan Amount  Loan Term  Interest Rate  Installment Subgrade  \
# 0       1077430         2500         60          15.27        59.83       C4
# 1       1076863        10000         36          13.49       339.31       C1
# 2       1075269         5000         36           7.90       156.46       A4
# 3       1069639         7000         60          15.96       170.08       C5
# 4       1072053         3000         36          18.64       109.43       E1
#
#    Employment Length (Years) Home Ownership  Annual Income Date of Issue  ...  \
# 0                          0           RENT        30000.0    2011-12-01  ...
# 1                         10           RENT        49200.0    2011-12-01  ...
# 2                          3           RENT        36000.0    2011-12-01  ...
# 3                          8           RENT        47004.0    2011-12-01  ...
# 4                          9           RENT        48000.0    2011-12-01  ...
#
# ...

# %%
dfl.columns
# Out:
# Index(['Applicant Id', 'loan Amount', 'Loan Term', 'Interest Rate',
#        'Installment', 'Subgrade', 'Employment Length (Years)',
#        'Home Ownership', 'Annual Income', 'Date of Issue', 'Loan Status',
#        'Purpose', 'Debt to Income Ratio',
#        'Number of Delinquencies Over Past Two Years',
#        'Number of Credit Inquiries Past 6 Months',
#        'Number of Open Credit Lines', 'Total Credit',
#        'Ratio of Total Credit Utilized', 'Total Number of Credit Lines',
#        'Number of Recent Bankruptcies', 'Federal Reserve Region',
#        'Date of Last Credit Pull', 'Grade', 'State of Address'],
#       dtype='object')

# %%
dfl1000 = dfl.sample(n=1000, random_state=1000)

# %%
dfl1000.to_json("loan_datatable.json", orient='records')
